# %% [markdown]
# # Практика

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as sts
import statsmodels.stats.weightstats as ssw
# %matplotlib inline

# %% [markdown]
# ## ЦПТ для различных распределений
# Возьмите то непрерывное распределение, которое вам больше всего понравится из списка доступных в модуле [scipy.stats](https://docs.scipy.org/doc/scipy/reference/stats.html).

# %% [markdown]
# ### Сгенерируйте примеры из распределения

# %%
# ваш код тут
# например вот такое распределение https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.cosine.html#scipy.stats.cosine
a = 1.1
dgamma_rv = sts.dgamma(a)
sample = dgamma_rv.rvs(100)
sample
# Out:
# array([-2.58871232,  1.30183634,  5.65244696,  0.87898803, -2.49973852,
#        -0.13587263,  1.5287506 ,  1.37107126, -3.019796  , -0.09381372,
#         0.41021452, -2.46771263,  0.74390882, -0.86445528, -0.59654877,
#         0.21704387,  0.29236183, -1.22290514, -0.33665688,  0.43179929,
#         2.1255507 ,  1.29260055, -0.57476706, -0.05398673,  2.29525557,
#        -3.82974631,  1.69219438,  0.74383171, -0.15112885, -0.06551233,
#         3.05977145,  0.05818023, -0.14330716,  0.37599712,  1.61814487,
#         2.18847575,  0.35617843, -2.62463364, -1.01645047, -0.43641519,
#         1.96044468, -1.46093719, -1.42293775,  0.42673229,  1.13651845,
#        -0.47922799,  0.20364766, -1.42205934, -0.2652281 ,  1.49216532,
#        -0.03237931,  0.20989338,  0.14887269, -3.46528739, -1.81428916,
#         0.91219345, -0.0127758 ,  0.63789522, -0.81463572, -0.01005789,
#        -2.40290216,  0.50623611,  0.22644828, -0.06202264,  0.06448559,
#         2.51796425, -0.01865649,  1.71465179,  0.60569229,  3.66621391,
#         2.73451762,  0.35564575,  0.12628951,  4.52024388, -0.07143245,
#        -2.48710075, -0.69567678,  0.23490132, -2.7873622 , -1.28037555,
#         0.84336503,  1.64000656, -0.67662404, -0.84050321,  0.7485973 ,
#         0.39315559,  0.24612129, -0.48458122,  0.42878258, -0.28669763,
#        -0.29497812, -0.03073763, -1.65612565, -0.54769206, -0.67239857,
#         0.30112763,  2.13789089,  2.52980659,  2.7571141 , -0.16091567])

# %%
sample.dtype
# Out:
# dtype('float64')

# %%
real_mean = dgamma_rv.mean() # настоящее среднее случайной величины
real_mean
# Out:
# 0.0

# %%
real_var = dgamma_rv.var() # настоящая дисперсия случайной величины
real_var
# Out:
# 2.3100000000000005

# %% [markdown]
# ### Постройте гистограмму выборки и теоретическую плотность распределения

# %%
# ваш код тут
plt.hist(sample, density=True)
x = np.linspace(-4,4,100)
pdf = dgamma_rv.pdf(x)
plt.plot(x, pdf, label='теоретическая плотность', alpha=0.5)
plt.legend()

# %%
sample_mean = sample.mean() # выборочное среднее
print(sample_mean)
sample_var = sample.var() # выборочная дисперсия
print(sample_var)
# Out:
# 0.15683465167250815
# 2.5600821185695195

# %% [markdown]
# ### Оценим распределение выборочного среднего для разных объёмов выборок
# Для этого постройте на одном полотне гистограмму выборочных средних и теоретическое распределение выборочных средних по ЦПТ для разных объёмов выборок.
#
# Для теоретического распределение используйте настоящие значения мат ожидания и дисперсии (не приближенные на основе выборки).

# %%
# ваш код тут

plt.figure(figsize=(16,9))
# сгенерируем много выборочных средних
for N in [10, 100, 1000, 10000]:
    means = []
    for i in range(1000):
         means.append(np.mean(dgamma_rv.rvs(N)))
    plt.hist(means, alpha=0.5)

plt.legend(['10', '100', '1000', '10000'])
plt.show()

# %%
norm_rv = sts.dgamma(a, loc=dgamma_rv.mean(), scale=dgamma_rv.std() / np.sqrt(N))
plt.hist(means, density=True, bins=40)
x = np.linspace(-0.1, 0.1, 100)
pdf = norm_rv.pdf(x)
plt.plot(x, pdf, label='Теоретическая плотность', alpha=0.5)
plt.legend()
plt.plot()
# Out:
# []

# %% [markdown]
# Как вы считаете, для выбранного распределения апроксимация распределения выборочного среднего работает хорошо или плохо?
# **Ваш ответ:** Неидеально, но скорее хорошо,чем плохо

# %% [markdown]
# ## Доверительный интервал на основе ЦПТ
# Возьмите данные для оттока телеком компании, и постройте доверительные интервалы для среднего значения total day calls, используя центральную предельную теорему в разбиении по колонке churn (ушел/не ушел).
#
# Для оценки дисперсии используйте несмещенную оценку (параметр ddof=1).
#
# Сделайте оценку с использованием явной формулы для z интервала, а затем с помощью функций
# `from statsmodels.stats.weightstats import _zconfint_generic`. Сравните результаты.
#
#
# Ссылка на данные: https://drive.google.com/file/d/1X_drKqoarnU2Sz2har7uSCsgyhh8Xtz8/view?usp=sharing

# %%
from IPython.core.display_functions import display

# либо загружаем из альтернативного хранилища
url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
df=pd.read_csv(url)
display(df)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# C:\Users\6801~1\AppData\Local\Temp/ipykernel_11280/2934369814.py in <module>
# ----> 1 from IPython.core.display_functions import display
#       2
#       3 # либо загружаем из альтернативного хранилища
#       4 url ="https://raw.githubusercontent.com/piton1/DS/Lesson_5/telecom_churn.csv"
#       5 df=pd.read_csv(url)
#
# ModuleNotFoundError: No module named 'IPython.core.display_functions'

# %%
df[['total day calls', 'churn']]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [135], in <cell line: 1>()
# ----> 1 df[['total day calls', 'churn' == True]]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3511, in DataFrame.__getitem__(self, key)
#    3509     if is_iterator(key):
#    3510         key = list(key)
# -> 3511     indexer = self.columns._get_indexer_strict(key, "columns")[1]
#    3513 # take() does not accept boolean indexers
#    3514 if getattr(indexer, "dtype", None) == bool:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5782, in Index._get_indexer_strict(self, key, axis_name)
#    5779 else:
#    5780     keyarr, indexer, new_indexer = self._reindex_non_unique(keyarr)
# -> 5782 self._raise_if_missing(keyarr, indexer, axis_name)
#    5784 keyarr = self.take(indexer)
#    5785 if isinstance(key, Index):
#    5786     # GH 42790 - Preserve name from an Index
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:5845, in Index._raise_if_missing(self, key, indexer, axis_name)
#    5842     raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    5844 not_found = list(ensure_index(key)[missing_mask.nonzero()[0]].unique())
# -> 5845 raise KeyError(f"{not_found} not in index")
#
# KeyError: '[False] not in index'

# %%
df_churn_true = df[(df['churn'] == True)][['total day calls', 'churn']]
df_churn_true
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: ('total day calls', 'churn')
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Input In [139], in <cell line: 1>()
# ----> 1 df_churn_true = df[(df['churn'] == True)]['total day calls', 'churn']
#       2 df_churn_true
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\frame.py:3505, in DataFrame.__getitem__(self, key)
#    3503 if self.columns.nlevels > 1:
#    3504     return self._getitem_multilevel(key)
# -> 3505 indexer = self.columns.get_loc(key)
#    3506 if is_integer(indexer):
#    3507     indexer = [indexer]
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\pandas\core\indexes\base.py:3623, in Index.get_loc(self, key, method, tolerance)
#    3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
# -> 3623     raise KeyError(key) from err
#    3624 except TypeError:
#    3625     # If we have a listlike key, _check_indexing_error will raise
#    3626     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3627     #  the TypeError.
#    3628     self._check_indexing_error(key)
#
# KeyError: ('total day calls', 'churn')

# %%
df.groupby(['churn'])['total day calls'].agg(['mean', 'count', 'std', 'var'])
# Out:
#              mean  count        std         var
# churn
# False  100.283158   2850  19.801157  392.085817
# True   101.335404    483  21.582307  465.795985

# %%
# df1['churn'].apply(pd.DataFrame)
# df1=df.groupby(['churn'])['total day calls'].agg(['mean', 'count', 'std', 'var'])
# mean_true = df1.loc[True, 'mean']
# mean_false = df1.loc[False, 'mean']
# var_true = df1.loc[True, 'var']
# var_false = df1.loc[False, 'var']
# std_true = df1.loc[True, 'std']
# std_false = df1.loc[False, 'std']
df_false = df[(df['churn'] == False)]["total day calls"]
df_true = df[(df['churn'] == True)]["total day calls"]

# %%
df_true.std()
# Out:
# 21.58230721307551

# %%
np.mean(df_true)
# Out:
# 101.33540372670808

# %%
data = df_true
N = 1
print("Доверительный интервал для среднего по цпт, если нам известна дисперсия: [{}, {}] ".format(
    np.mean(data) - 1.96 * data.std() / np.sqrt(N), np.mean(data) + 1.96 * data.std() / np.sqrt(N)
))
print("Доверительный интервал для среднего по цпт интервальная оценка: {} ".format(
    sts.norm.interval(alpha=0.95, loc=np.mean(data),
                      scale=np.std(data, ddof=1)/np.sqrt(N)) # alternative 'two-sided' only
))

print("Доверительный интервал для среднего по цпт методом _zconfint_generic: {} ".format(
    ssw._zconfint_generic(np.mean(data),  np.std(data, ddof=1), alpha=0.95, alternative='two-sided')
))
# Out:
# Доверительный интервал для среднего по цпт, если нам известна дисперсия: [59.03408158908008, 143.63672586433609]
# Доверительный интервал для среднего по цпт интервальная оценка: (59.03485888580106, 143.63594856761512)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [6], in <cell line: 11>()
#       3 print("Доверительный интервал для среднего по цпт, если нам известна дисперсия: [{}, {}] ".format(
#       4     np.mean(data) - 1.96 * data.std() / np.sqrt(N), np.mean(data) + 1.96 * data.std() / np.sqrt(N)
#       5 ))
#       6 print("Доверительный интервал для среднего по цпт интервальная оценка: {} ".format(
#       7     sts.norm.interval(alpha=0.95, loc=np.mean(data),
#       8                       scale=np.std(data, ddof=1)/np.sqrt(N)) # alternative 'two-sided' only
#       9 ))
#      11 print("Доверительный интервал для среднего по цпт методом _zconfint_generic: {} ".format(
# ---> 12     ssw._zconfint_generic(np.mean(data),  np.std(data, ddof=1), alpha=0.95, alternative='two-sided')
#      13 ))
#
# NameError: name 'ssw' is not defined

# %%
df[df['churn'] == False]['total day calls']
# Out:
# 0       110
# 1       123
# 2       114
# 3        71
# 4       113
#        ...
# 3328     77
# 3329     57
# 3330    109
# 3331    105
# 3332    113
# Name: total day calls, Length: 2850, dtype: int64
